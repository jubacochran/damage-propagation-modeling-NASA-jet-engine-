# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


rul_FD001_training = pd.read_csv('CMAPSSData/test_FD001.txt', delim_whitespace=True)
rul_1 = pd.read_csv('CMAPSSData/RUL_FD001.txt')
print(rul_FD001_training.info())
rul_FD001_training.isnull().sum().plot.bar()
rul_FD001_training.isna().sum().plot.bar()
print('============')
print(rul_1.describe())
print(rul_1.head(3))
print(rul_1.info())

#Initialize list of skewed columns list
columns_to_normalize = []

# Loop through each column and create an individual plot
for column in rul_FD001_training.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=rul_FD001_training[column])
    plt.title(f'Distribution of {column}')
    plt.show()
    print(rul_FD001_training[column].skew())
    skewness = rul_FD001_training[column].skew()
    print(f'Skewness of {column}: {skewness}')
    
    # Check if the skewness is outside the range of -0.5 to 0.5
    if skewness < -0.5 or skewness > 0.5:
        columns_to_normalize.append(column)

# Print the columns that need normalization
print(f'Columns that need normalization: {columns_to_normalize}')

print(rul_FD001_training.head(8))

rul_1.plot.line()
print(rul_1.describe())
rul_FD001_training['1.1'].plot.line()

#Dist 21.61
#Dist 9050.17
#Dist 47.20
#Dist 8125.55
#Dist 1.1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13095 entries, 0 to 13094
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1        13095 non-null  int64
#  1   1.1      13095 non-null  int64
#  2   0.0023   13095 non-null  float64
#  3   0.0003   13095 non-null  float64
#  4   100.0    13095 non-null  float64
#  5   518.67   13095 non-null  float64
#  6   643.02   13095 non-null  float64
#  7   1585.29  13095 non-null  float64
#  8   1398.21  13095 non-null  float64
#  9   14.62    13095 non-null  float64
#  10  21.61    13095 non-null  float64
#  11  553.90   13095 non-null  float64
#  12  2388.04  13095 non-null  float64
#  13  9050.17  13095 non-null  float64
#  14  1.30     13095 non-null  float64
#  15  47.20    13095 non-null  float64
#  16  521.72   13095 non-null  float64
#  17  2388.03  13095 non-null  float64
#  18  8125.55  13095 non-null  float64
#  19  8.4052   13095 non-null  float64
#  20  0.03     13095 non-null  float64
#  21  392      13095 non-null  int64
#  22  2388     13095 non-null  int64
#  23  100.00   13095 non-null  float64
#  24  38.86    13095 non-null  float64
#  25  23.3735  13095 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 2.6 MB
# None
# ============
#              112
# count   99.000000
# mean    75.151515
# std     41.813816
# min      7.000000
# 25%     31.500000
# 50%     85.000000
# 75%    112.000000
# max    145.000000
#    112
# 0    98
# 1    69
# 2    82
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   112     99 non-null     int64
# dtypes: int64(1)
# memory usage: 924.0 bytes
# None
# <ipython-input-51-09411e512e07>:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   rul_FD001_training = pd.read_csv('CMAPSSData/test_FD001.txt', delim_whitespace=True)
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0017691927235766868
# Skewness of 1: 0.0017691927235766868
# 0.7243692254701374
# Skewness of 1.1: 0.7243692254701374
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# -0.002130510475998736
# Skewness of 0.0023: -0.002130510475998736
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.016512479386336158
# Skewness of 0.0003: 0.016512479386336158
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 100.0: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 518.67: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.22512112808244922
# Skewness of 643.02: 0.22512112808244922
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.1579430974302105
# Skewness of 1585.29: 0.1579430974302105
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.3419723595650279
# Skewness of 1398.21: 0.3419723595650279
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 14.62: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# -5.5175579165987925
# Skewness of 21.61: -5.5175579165987925
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# -0.345642479211416
# Skewness of 553.90: -0.345642479211416
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.3032887522217694
# Skewness of 2388.04: 0.3032887522217694
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 1.6546125767282374
# Skewness of 9050.17: 1.6546125767282374
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 1.30: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.4043397354938117
# Skewness of 47.20: 0.4043397354938117
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# -0.381527748731371
# Skewness of 521.72: -0.381527748731371
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.290402902656717
# Skewness of 2388.03: 0.290402902656717
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 1.3577232953002387
# Skewness of 8125.55: 1.3577232953002387
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.2654215824221287
# Skewness of 8.4052: 0.2654215824221287
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 0.03: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.21659737829526535
# Skewness of 392: 0.21659737829526535
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 2388: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# 0.0
# Skewness of 100.00: 0.0
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# -0.23329644696709242
# Skewness of 38.86: -0.23329644696709242
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# -0.24713367756821347
# Skewness of 23.3735: -0.24713367756821347
# Columns that need normalization: ['1.1', '21.61', '9050.17', '8125.55']
#    1  1.1  0.0023  0.0003  100.0  518.67  643.02  1585.29  1398.21  14.62  \
# 0  1    2 -0.0027 -0.0003  100.0  518.67  641.71  1588.45  1395.42  14.62
# 1  1    3  0.0003  0.0001  100.0  518.67  642.46  1586.94  1401.34  14.62
# 2  1    4  0.0042  0.0000  100.0  518.67  642.44  1584.12  1406.42  14.62
# 3  1    5  0.0014  0.0000  100.0  518.67  642.51  1587.19  1401.92  14.62
# 4  1    6  0.0012  0.0003  100.0  518.67  642.11  1579.12  1395.13  14.62
# 5  1    7 -0.0000  0.0002  100.0  518.67  642.11  1583.34  1404.84  14.62
# 6  1    8  0.0006 -0.0000  100.0  518.67  642.54  1580.89  1400.89  14.62
# 7  1    9 -0.0036  0.0000  100.0  518.67  641.88  1593.29  1412.28  14.62
#
#    ...  521.72  2388.03  8125.55  8.4052  0.03  392  2388  100.00  38.86  \
# 0  ...  522.16  2388.06  8139.62  8.3803  0.03  393  2388   100.0  39.02
# 1  ...  521.97  2388.03  8130.10  8.4441  0.03  393  2388   100.0  39.08
# 2  ...  521.38  2388.05  8132.90  8.3917  0.03  391  2388   100.0  39.00
# 3  ...  522.15  2388.03  8129.54  8.4031  0.03  390  2388   100.0  38.99
# 4  ...  521.92  2388.08  8127.46  8.4238  0.03  392  2388   100.0  38.91
# 5  ...  522.01  2388.06  8134.97  8.3914  0.03  391  2388   100.0  38.85
# 6  ...  522.09  2388.06  8125.93  8.4213  0.03  393  2388   100.0  39.05
# 7  ...  522.03  2388.05  8134.15  8.4353  0.03  391  2388   100.0  39.10
#
#    23.3735
# 0  23.3916
# 1  23.4166
# 2  23.3737
# 3  23.4130
# 4  23.3467
# 5  23.3952
# 6  23.3224
# 7  23.4521
#
# [8 rows x 26 columns]
#              112
# count   99.000000
# mean    75.151515
# std     41.813816
# min      7.000000
# 25%     31.500000
# 50%     85.000000
# 75%    112.000000
# max    145.000000
# <Axes: >
