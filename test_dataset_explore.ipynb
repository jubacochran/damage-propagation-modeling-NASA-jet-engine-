# %%
from FirstSteps import column_converter,feature_skew_check
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import QuantileTransformer, PowerTransformer,MinMaxScaler
import scipy.stats as stats

# %%
FD001_data_tuple = column_converter('CMAPSSData/test_FD001.txt')

FD001_data = FD001_data_tuple[0] #Dataframe
sensor_names = FD001_data_tuple[1] #List of sensor names
# Out:
# no failures converting dataframe columns
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13095 entries, 0 to 13094
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Engine                                13095 non-null  int64
#  1   Cycles                                13095 non-null  int64
#  2   Operational Setting 1                 13095 non-null  float64
#  3   Operational Setting 2                 13095 non-null  float64
#  4   Operational Setting 3                 13095 non-null  float64
#  5   Fan inlet temperature ◦R              13095 non-null  float64
#  6   LPC outlet temperature ◦R             13095 non-null  float64
#  7   HPC outlet temperature ◦R             13095 non-null  float64
#  8   LPT outlet temperature ◦R             13095 non-null  float64
#  9   Fan inlet Pressure psia               13095 non-null  float64
# ...

# %%
feature_skew_check(FD001_data,sensor_names)
# Out:
# Skewness of Fan inlet temperature ◦R: 0.0
# Skewness of LPC outlet temperature ◦R: 0.22512112808244922
# Skewness of HPC outlet temperature ◦R: 0.1579430974302105
# Skewness of LPT outlet temperature ◦R: 0.3419723595650279
# Skewness of Fan inlet Pressure psia: 0.0
# Skewness of bypass-duct pressure psia: -5.5175579165987925
# Skewness of HPC outlet pressure psia: -0.345642479211416
# Skewness of Physical fan speed rpm: 0.3032887522217694
# Skewness of Physical core speed rpm: 1.6546125767282374
# Skewness of Engine pressure ratioP50/P2: 0.0
# Skewness of HPC outlet Static pressure psia: 0.4043397354938117
# Skewness of Ratio of fuel flow to Ps30 pps/psia: -0.381527748731371
# Skewness of Corrected fan speed rpm: 0.290402902656717
# Skewness of Corrected core speed rpm: 1.3577232953002387
# Skewness of Bypass Ratio : 0.2654215824221287
# Skewness of Burner fuel-air ratio: 0.0
# Skewness of Bleed Enthalpy: 0.21659737829526535
# Skewness of Required fan speed: 0.0
# ...

# %%
max_engine_cycles = FD001_data.groupby("Engine")[['Cycles']].agg(max)
print(type(max_engine_cycles.info()))
print(max_engine_cycles)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 1 to 100
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cycles  100 non-null    int64
# dtypes: int64(1)
# memory usage: 1.6 KB
# <class 'NoneType'>
#         Cycles
# Engine
# 1           31
# 2           49
# 3          126
# 4          106
# 5           98
# ...        ...
# 96          97
# 97         134
# 98         121
# 99          97
# 100        198
#
# [100 rows x 1 columns]
